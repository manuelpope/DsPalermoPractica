# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelpope/DsPalermoPractica/blob/master/logRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import SGDClassifier
import pandas as pd
import numpy as np

# %%
path= '/content/drive/My Drive/Colab Notebooks/cleanDatavfromColab.csv'
data = pd.read_csv(path)
data.head()
data['name'].count()
# Out:
# 294121

# %%
#split the data frame test y train 
y= data['success']
listLenghts= []
for i in range(0,data['name'].count()):
  listLenghts.append(len(data['name'].iloc[i]))
data['name']= listLenghts

X = data.drop(columns=['Unnamed: 0','success', 'ID','usd pledged','state','pledged','launched','deadline','inUSDPledged'])
X.head(10)
# Out:
#    name        category main_category  ... inUSDGoal  gap        range
# 0    31          Poetry    Publishing  ...    1240.0   58  muy pequeño
# 1    14  Narrative Film  Film & Video  ...   45000.0   45   muy grande
# 2    49           Music         Music  ...    5000.0   30      mediano
# 3    58    Film & Video  Film & Video  ...   19500.0   55       grande
# 4    20     Restaurants          Food  ...   50000.0   35   muy grande
# 5    60            Food          Food  ...    1000.0   20  muy pequeño
# 6    49          Drinks          Food  ...   25000.0   44   muy grande
# 7    53  Product Design        Design  ...  125000.0   35   muy grande
# 8    57     Documentary  Film & Video  ...   65000.0   30   muy grande
# 9    19      Nonfiction    Publishing  ...    1850.0   30      pequeño
#
# [10 rows x 10 columns]

# %%
X= pd.get_dummies(X, columns=['range'])

X= pd.get_dummies(X, columns=['category'])


X= pd.get_dummies(X, columns=['main_category'])

X= pd.get_dummies(X, columns=['currency'])

X= pd.get_dummies(X, columns=['country'])



X.head()
# Out:
#    name     goal  backers  ...  country_SE  country_SG  country_US
# 0    31   1000.0        0  ...           0           0           0
# 1    14  45000.0        3  ...           0           0           1
# 2    49   5000.0        1  ...           0           0           1
# 3    58  19500.0       14  ...           0           0           1
# 4    20  50000.0      224  ...           0           0           1
#
# [5 rows x 217 columns]

# %%
from sklearn.model_selection import train_test_split

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y,test_size=0.3, random_state=1)

# %%
len(Xtrain),len(Xtest),len(ytrain),len(ytest)
Xtrain.head()
# Out:
#         name     goal  backers  ...  country_SE  country_SG  country_US
# 293345    22  25000.0      141  ...           0           0           1
# 235851    28   5000.0      234  ...           0           0           1
# 108081    13   2000.0       56  ...           0           0           0
# 197635    49    350.0        8  ...           0           0           1
# 78503     59   2500.0       15  ...           0           0           0
#
# [5 rows x 217 columns]

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression


clf = LogisticRegression(random_state=1).fit(Xtrain, ytrain)
re1 = clf.predict(Xtest)
re2 = clf.predict_proba(Xtest)
clf.score(Xtest,ytest)
#clf = SGDClassifier(loss="hinge", penalty='l2', max_iter=5)
#clf.fit(Xtrain, ytrain)
# Out:
# 0.8916554279950588

# %%
Xproba  = pd.DataFrame(re2, columns = ['probafail', 'probawork'])
#Xtest['pfail'] = np.float64(np.array(Xproba['probafail']))
#Xtest['pwork'] = np.float64(np.array(Xproba['probawork']))
#Xtest.tail(10)

# %%
clf.intercept_
clf.coef_
#clf.predict_proba(Xtrain) #problem with hinge , cae del 87 a el 67 con esta funcion de perdidas.
clf.score(Xtest,ytest)
#dataf = pd.DataFrame(clf.predict_proba(Xtrain))# hara perder precision
# Out:
# 0.8916554279950588

# %%
#Xtest['proba'] = dataf
#Xtest.describe()

# %%
dr1= pd.DataFrame(result)
dr1.head()
# Out:
#    0
# 0  0
# 1  0
# 2  0
# 3  0
# 4  0

# %%
from sklearn.metrics import classification_report , confusion_matrix

# %%
matrixConf = confusion_matrix(ytest, clf.predict(Xtest))

# %%
#A11 true negative prediction
#A21 false negative prediction
#A12 false positive prediction
#A22 true positive prediction

print(classification_report(ytest,clf.predict(Xtest)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92     56891
#            1       0.92      0.76      0.83     31346
#
#     accuracy                           0.89     88237
#    macro avg       0.90      0.86      0.88     88237
# weighted avg       0.89      0.89      0.89     88237

# %%
mcunf = np.array(matrixConf)
mcunf
# Out:
# array([[54828,  2063],
#        [ 7497, 23849]])

# %%
mcunf = np.reshape(mcunf,(4))
mcunf
acc = (mcunf[3]+ mcunf[0])/len(ytest)
reCall = mcunf[3]/(mcunf[3]+ mcunf[1])
prec = mcunf[3]/(mcunf[3]+ mcunf[2])
prec, reCall, acc
# Out:
# (0.760830728003573, 0.9203843778944119, 0.8916554279950588)

# %%
f1 = 2*prec*reCall/(prec+reCall)
f1
# Out:
# 0.8330364315903453

# %%
from scipy import stats
a=clf.predict(Xtest)
neg = [ x for x in a if x != 1]
l= len(Xtest)
stats.binom_test(len(neg), n=l, p=0.70, alternative='greater')
# que la probabilidad de fallar sea mayor al 70 % es de :
# Out:
# 1.9657499666731854e-05

# %%
stats.describe(a)
# Out:
# DescribeResult(nobs=88237, minmax=(0, 1), mean=0.2936636558359872, variance=0.20742766387843847, skewness=0.906097328689124, kurtosis=-1.1789876309424332)

# %%
result = np.array(clf.predict(Xtest))
dr = pd.DataFrame(Xtest)
dr['resultPredict']= np.array(dr1)
dr['resultReal']= np.array(ytest)

dfinalAciertos = dr.query("resultPredict == resultReal")
dr.tail(10)
# Out:
#         name      goal  backers  ...  country_US  resultPredict  resultReal
# 62858     30    5000.0        0  ...           1              0           0
# 55574     49    2000.0       39  ...           1              0           1
# 146760    39   10000.0        2  ...           1              0           0
# 2654      52       1.0        9  ...           1              1           1
# 201762    27    8000.0       60  ...           1              0           1
# 1178      46    1267.0        2  ...           1              1           0
# 172290    30  100000.0        2  ...           1              0           0
# 149470    55   25000.0        3  ...           0              0           0
# 281900     8    7000.0        0  ...           0              0           0
# 153564    60   12000.0        2  ...           1              0           0
#
# [10 rows x 219 columns]

# %%
import re
dictResultSum={}
for column in dfinalAciertos.columns:

  x = re.findall("^cat", column)
  if x:
    dictResultSum[column]= dfinalAciertos[column].sum()

# %%
max_key = max(dictResultSum, key=dictResultSum.get)
min_key = min(dictResultSum, key=dictResultSum.get)
max_key ,min_key
# Out:
# ('category_Product Design', 'category_Letterpress')

# %%
dictResultSum={}
for column in dfinalAciertos.columns:

  x = re.findall("^main", column)
  if x:
    dictResultSum[column]= dfinalAciertos[column].sum()

# %%
max_key = max(dictResultSum, key=dictResultSum.get)
min_key = min(dictResultSum, key=dictResultSum.get)
max_key ,min_key
# Out:
# ('main_category_Film & Video', 'main_category_Dance')

# %%
dictResultSum={}
for column in dfinalAciertos.columns:

  x = re.findall("^range", column)
  if x:
    dictResultSum[column]= dfinalAciertos[column].sum()

# %%
max_key = max(dictResultSum, key=dictResultSum.get)
min_key = min(dictResultSum, key=dictResultSum.get)
max_key ,min_key
# Out:
# ('range_muy grande', 'range_pequeño')

# %%
Xtest['pfail'] = np.float64(np.array(Xproba['probafail']))
Xtest['pwork'] = np.float64(np.array(Xproba['probawork']))
Xtest.head(15)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         name     goal  backers  ...  resultReal     pfail     pwork
# 54404     17  30000.0        4  ...           0  0.997657  0.002343
# 241730    22   3667.0       40  ...           0  0.441422  0.558578
# 255188    36  28000.0       19  ...           0  0.994261  0.005739
# 278960    34  39000.0        7  ...           0  0.999608  0.000392
# 213256    24   3700.0        6  ...           0  0.758433  0.241567
# 291578    53  10000.0       15  ...           0  0.886762  0.113238
# 217603    17  15000.0        4  ...           0  0.933356  0.066644
# 138539    44   1000.0       30  ...           1  0.555748  0.444252
# 177217    55   3500.0       48  ...           1  0.367561  0.632439
# 162575     5    220.0        0  ...           0  0.662199  0.337801
# 102902    13   2500.0       46  ...           1  0.325769  0.674231
# 13667     31    600.0        0  ...           0  0.698443  0.301557
# 95585     20   5000.0       15  ...           1  0.560094  0.439906
# 216146    18   2000.0       81  ...           1  0.099095  0.900905
# 165280    47  10000.0        0  ...           0  0.957876  0.042124
#
# [15 rows x 221 columns]

# %%
Xtest.head()
# Out:
#         name     goal  backers  ...  resultReal     pfail     pwork
# 54404     17  30000.0        4  ...           0  0.997657  0.002343
# 241730    22   3667.0       40  ...           0  0.441422  0.558578
# 255188    36  28000.0       19  ...           0  0.994261  0.005739
# 278960    34  39000.0        7  ...           0  0.999608  0.000392
# 213256    24   3700.0        6  ...           0  0.758433  0.241567
#
# [5 rows x 221 columns]

# %%
from sklearn import metrics
y = (Xtest['resultPredict'])
pred = Xtest['pwork']
fpr, tpr, thresholds = metrics.roc_curve(ytest, pred)
metrics.auc(fpr, tpr)
# Out:
# 0.9541562299277567
